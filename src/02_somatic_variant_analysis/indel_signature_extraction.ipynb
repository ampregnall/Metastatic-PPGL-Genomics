# %%
import pandas as pd
import numpy as np
import musical
import matplotlib.pyplot as plt
from SigProfilerExtractor import sigpro as sig

# %%
# Load data
df1_path = "/Users/ampregnall/Documents/research/Metastatic-PPGL-Genomics/data/processed/mutational_signatures/input/output/ID/mPPGL.ID83.all"
df1 = pd.read_table(df1_path)
df1.head()
# Out:
#   MutationType  PP002-DZ3A  PP002-DZ4A  PP002-DZ5A  PP008-DZ2A  PP009-DZ1B  \
# 0    1:Del:C:0           0           0           1          25           0
# 1    1:Del:C:1           0           0           0          16           0
# 2    1:Del:C:2           0           0           0           2           0
# 3    1:Del:C:3           0           0           0          11           0
# 4    1:Del:C:4           0           0           0           3           0
#
#    PP009-DZ2B  PP010-DZ1A  PP010-DZ5A  PP010-F2  ...  PP253-DZ1A  PP253-DZ2A  \
# 0           0           0           0         0  ...           2           1
# 1           0           0           0         0  ...           1           0
# 2           0           0           0         0  ...           0           0
# 3           0           0           0         0  ...           0           0
# 4           0           0           0         0  ...           0           0
#
# ...

# %%
sig.sigProfilerExtractor(
        "matrix",
        "/Users/ampregnall/Documents/research/Metastatic-PPGL-Genomics/data/processed/mutational_signatures/SigProfilerExtractor",
        df1,
        opportunity_genome="GrCh38",
        exome=True,
        minimum_signatures=1,
        maximum_signatures=10,
        cpu=4,
    )
# Out:
# ************** Reported Current Memory Use: 0.25 GB *****************
#
# Extracting signature 1 for mutation type INDEL
# The matrix normalizing cutoff is 8300
#
#
# Time taken to collect 100 iterations for 1 signatures is 122.84 seconds
# Optimization time is 6.8694541454315186 seconds
# The reconstruction error is 0.362, average process stability is 1.0 and
# the minimum process stability is 1.0 for 1 signatures
#
#
# Extracting signature 2 for mutation type INDEL
# The matrix normalizing cutoff is 8300
#
#
# Time taken to collect 100 iterations for 2 signatures is 149.73 seconds
# Optimization time is 4.378026008605957 seconds
# The reconstruction error is 0.1178, average process stability is 1.0 and
# the minimum process stability is 1.0 for 2 signatures
#
#
# Extracting signature 3 for mutation type INDEL
# The matrix normalizing cutoff is 8300
#
#
# Time taken to collect 100 iterations for 3 signatures is 234.88 seconds
# Optimization time is 3.9128968715667725 seconds
# ...

# %%
# Load data
df2_path = "/Users/ampregnall/Documents/research/Metastatic-PPGL-Genomics/data/processed/mutational_signatures/input/output/SBS/mPPGL.SBS96.all"
df2 = pd.read_table(df2_path)
df2.head()
# Out:
#   MutationType  PP002-DZ3A  PP002-DZ4A  PP002-DZ5A  PP008-DZ2A  PP009-DZ1B  \
# 0      A[C>A]A           6          25           1         479          34
# 1      A[C>A]C           0           2           1         241          30
# 2      A[C>A]G           1           0           0         176           9
# 3      A[C>A]T           3           1           0         271          26
# 4      A[C>G]A           0           0           0          89           1
#
#    PP009-DZ2B  PP010-DZ1A  PP010-DZ5A  PP010-F2  ...  PP253-DZ1A  PP253-DZ2A  \
# 0          71           0           1         0  ...          16           4
# 1          47           0           0         0  ...           9           9
# 2          17           0           1         0  ...          12           0
# 3          42           0           0         1  ...           8           2
# 4           1           0           1         0  ...           2           0
#
# ...

# %%
sig.sigProfilerExtractor(
        "matrix",
        "/Users/ampregnall/Documents/research/Metastatic-PPGL-Genomics/data/processed/mutational_signatures/SigProfilerExtractor_SBS",
        df2,
        opportunity_genome="GrCh38",
        exome=True,
        minimum_signatures=1,
        maximum_signatures=10,
        cpu=4,
    )
# Out:
# ************** Reported Current Memory Use: 0.53 GB *****************
#
# Extracting signature 1 for mutation type 96
# The matrix normalizing cutoff is 9600
#
#
# Time taken to collect 100 iterations for 1 signatures is 52.98 seconds
# Optimization time is 3.2034690380096436 seconds
# The reconstruction error is 0.6354, average process stability is 1.0 and
# the minimum process stability is 1.0 for 1 signatures
#
#
# Extracting signature 2 for mutation type 96
# The matrix normalizing cutoff is 9600
#
#
# Time taken to collect 100 iterations for 2 signatures is 76.09 seconds
# Optimization time is 2.6622629165649414 seconds
# The reconstruction error is 0.2537, average process stability is 1.0 and
# the minimum process stability is 0.99 for 2 signatures
#
#
# Extracting signature 3 for mutation type 96
# The matrix normalizing cutoff is 9600
#
#
# Time taken to collect 100 iterations for 3 signatures is 115.14 seconds
# Optimization time is 2.6770448684692383 seconds
# ...
